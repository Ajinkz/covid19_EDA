# %%
import requests
import pandas as pd
import io

# %%
url1 = 'https://api.covid19india.org'
data1 = requests.get(url1)

# %%
datdata1.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n  <head>\n    <meta charset="UTF-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n<!-- Begin Jekyll SEO tag v2.6.1 -->\n<title>COVID19-India API | api</title>\n<meta name="generator" content="Jekyll v3.8.7" />\n<meta property="og:title" content="COVID19-India API" />\n<meta property="og:locale" content="en_US" />\n<meta name="description" content="Our Database" />\n<meta property="og:description" content="Our Database" />\n<link rel="canonical" href="https://api.covid19india.org/" />\n<meta property="og:url" content="https://api.covid19india.org/" />\n<meta property="og:site_name" content="api" />\n<script type="application/ld+json">\n{"@type":"WebSite","url":"https://api.covid19india.org/","headline":"COVID19-India API","name":"api","description":"Our Database","@context":"https://schema.org"}</script>\n<!-- End Jekyll SEO tag -->\n\n    <link rel="styles
# ...

# %%
from IPython.core.display import display, HTML
display(HTML(data1.text))
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#   <head>
#     <meta charset="UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <!-- Begin Jekyll SEO tag v2.6.1 -->
# <title>COVID19-India API | api</title>
# <meta name="generator" content="Jekyll v3.8.7" />
# <meta property="og:title" content="COVID19-India API" />
# <meta property="og:locale" content="en_US" />
# <meta name="description" content="Our Database" />
# <meta property="og:description" content="Our Database" />
# <link rel="canonical" href="https://api.covid19india.org/" />
# <meta property="og:url" content="https://api.covid19india.org/" />
# <meta property="og:site_name" content="api" />
# <script type="application/ld+json">
# {"@type":"WebSite","url":"https://api.covid19india.org/","headline":"COVID19-India API","name":"api","description":"Our Database","@context":"https://schema.org"}</script>
# <!-- End Jekyll SEO tag -->
#
# ...

# %%
url2 = 'https://api.covid19india.org/csv/latest/raw_data.csv'
data2 = requests.get(url2)

# %%
data2=requests.get(url2).content
df=pd.read_csv(io.StringIO(data2.decode('utf-8')))

# %%
df
# Out:
#        Patient Number State Patient Number Date Announced  \
# 0                 1.0             KL-TS-P1     30/01/2020
# 1                 2.0             KL-AL-P1     02/02/2020
# 2                 3.0             KL-KS-P1     03/02/2020
# 3                 4.0                DL-P1     02/03/2020
# 4                 5.0                TS-P1     02/03/2020
# ...               ...                  ...            ...
# 28178             NaN                  NaN     22/04/2020
# 28179             NaN                  NaN     24/04/2020
# 28180             NaN                  NaN     24/04/2020
# 28181             NaN                  NaN     25/04/2020
# 28182             NaN                  NaN     25/04/2020
#
#        Estimated Onset Date Age Bracket Gender             Detected City  \
# 0                       NaN          20      F                  Thrissur
# 1                       NaN         NaN    NaN                 Alappuzha
# ...

# %%
url3 = 'https://api.covid19india.org/zones.json'
data3 = requests.get(url3)
df3 = pd.read_json(data3.text)

# %%
for i in df3['zones']:
    print(i['district'],'|',i['zone'])
# Out:
# Nicobars | Green
# North and Middle Andaman | Green
# South Andaman | Red
# Anantapur | Orange
# Chittoor | Red
# East Godavari | Orange
# Guntur | Red
# Krishna | Red
# Kurnool | Red
# Prakasam | Orange
# S.P.S. Nellore | Red
# Srikakulam | Orange
# Visakhapatnam | Orange
# Vizianagaram | Orange
# West Godavari | Orange
# Y.S.R. Kadapa | Orange
# Anjaw | Green
# Changlang | Green
# East Kameng | Green
# East Siang | Green
# Kamle | Green
# Kra Daadi | Green
# Kurung Kumey | Green
# Lepa Rada | Green
# Lohit | Green
# Longding | Green
# Lower Dibang Valley | Green
# Lower Siang | Green
# Lower Subansiri | Green
# Namsai | Green
# Pakke Kessang | Green
# Papum Pare | Green
# Shi Yomi | Green
# Siang | Green
# Tawang | Green
# Tirap | Green
# Upper Dibang Valley | Green
# Upper Siang | Green
# Upper Subansiri | Green
# West Kameng | Green
# West Siang | Green
# Baksa | Green
# Barpeta | Green
# Biswanath | Green
# Bongaigaon | Red
# Cachar | Orange
# Charaideo | Green
# ...
